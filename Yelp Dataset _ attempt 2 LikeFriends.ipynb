# %%
import pandas as pd

# %%
bus =  pd.read_csv('business.csv')

# %%
user= pd.read_csv('user_data.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
user['friends']=user["friends"].apply(lambda x: str(x).split(','))

# %%
user.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           4.03                1                0                 1
# 1           3.63                1                0                 1
# 2           3.71                0                0                 0
# 3           4.85                0                0                 0
# 4           4.08               80                0                80
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0               2                0                0                1
# 1               1                0                0                0
# 2               0                0                0                1
# 3               1                0                0                0
# 4              28                1                1               16
#
#    compliment_photos  compliment_plain         ...           cool  \
# ...

# %%
bus_ny = bus[bus['state']=='NY']

# %%
bus_ny.head()
# Out:
#        Unnamed: 0           address  \
# 595           595  1038 State Rt 11
# 9916         9916       109 Lake St
# 22869       22869   876 State Rt 11
# 27152       27152        1038 Rt 11
# 47513       47513       133 Lake St
#
#                                               attributes  \
# 595    {'Ambience': "{'touristy': False, 'hipster': F...
# 9916   {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 22869  {'RestaurantsTakeOut': 'True', 'OutdoorSeating...
# 27152  {'HasTV': 'True', 'Alcohol': "u'none'", 'Busin...
# 47513  {'BikeParking': 'True', 'HasTV': 'False', 'Res...
#
#                   business_id  \
# 595    Ya-HZZrzMWYSBtGyLajDQg
# 9916   f5Pg89x-2xek78E9KHMhNg
# 22869  Uz77JHl5e6zlGa-71-6_dA
# 27152  xkha6iK_PLsUqnFB-CJW5g
# 47513  sY2TrIpQaS8kFDI8GRGS3Q
#
#                                               categories          city  \
# 595    Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# ...

# %%
review = pd.read_csv('review.csv')

# %%
bus_review = pd.merge(bus_ny,review,how='inner',on='business_id')

# %%
bus_review.head()
# Out:
#    Unnamed: 0           address  \
# 0         595  1038 State Rt 11
# 1         595  1038 State Rt 11
# 2         595  1038 State Rt 11
# 3         595  1038 State Rt 11
# 4        9916       109 Lake St
#
#                                           attributes             business_id  \
# 0  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 1  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 2  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 3  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 4  {'RestaurantsGoodForGroups': 'True', 'BikePark...  f5Pg89x-2xek78E9KHMhNg
#
#                                           categories          city  \
# 0  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# 1  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# 2  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# ...

# %%
bus_review.pop('stars_x')
bus_review.head()
# Out:
#    Unnamed: 0           address  \
# 0         595  1038 State Rt 11
# 1         595  1038 State Rt 11
# 2         595  1038 State Rt 11
# 3         595  1038 State Rt 11
# 4        9916       109 Lake St
#
#                                           attributes             business_id  \
# 0  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 1  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 2  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 3  {'Ambience': "{'touristy': False, 'hipster': F...  Ya-HZZrzMWYSBtGyLajDQg
# 4  {'RestaurantsGoodForGroups': 'True', 'BikePark...  f5Pg89x-2xek78E9KHMhNg
#
#                                           categories          city  \
# 0  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# 1  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# 2  Convenience Stores, Hot Dogs, Gas Stations, Bu...     Champlain
# ...

# %%
bus_review.to_csv('dummy_bus.csv')

# %%
user[user['user_id']=='Y3q4_O6f-4bdlBd5ZByNWQ']
# Out:
#         average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 541586           3.21                0                0                 0
#
#         compliment_hot  compliment_list  compliment_more  compliment_note  \
# 541586               1                0                0                2
#
#         compliment_photos  compliment_plain         ...           cool  elite  \
# 541586                  0                 0         ...             18    NaN
#
#         fans                                            friends  funny  \
# 541586     0  [VKriBUODDKCcDOfmgoeSUQ,  v3GtDpHEqqf0mXjIhqK6...     34
#
#           name  review_count useful                 user_id  \
# 541586  Gordon           105     58  Y3q4_O6f-4bdlBd5ZByNWQ
#
#               yelping_since
# 541586  2011-04-23 19:42:51
#
# [1 rows x 22 columns]

# %%
bus_review = pd.read_csv('dummy_bus.csv')
bus_review.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                          address  \
# 0           0         32107                       28 Park St
# 1           1         32107                       28 Park St
# 2           2         32107                       28 Park St
# 3           3         83948  18471 E Queen Creek Rd, Ste 104
# 4           4         83948  18471 E Queen Creek Rd, Ste 104
#
#                                           attributes             business_id  \
# 0  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...  WwwYZakdSQM9174gdZdUIA
# 1  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...  WwwYZakdSQM9174gdZdUIA
# 2  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...  WwwYZakdSQM9174gdZdUIA
# 3                                                NaN  W839iVmIb3dKrU_-eyOhQA
# 4                                                NaN  W839iVmIb3dKrU_-eyOhQA
#
#                                           categories         city  \
# ...

# %%
for b in ['WwwYZakdSQM9174gdZdUIA']:
    for u in bus_review[bus_review['business_id']==b]['user_id']:
        for F in user[user['user_id']==u]['friends']:
            for f in F:
                if f in (bus_review[bus_review['business_id']==b]['user_id']).tolist():
                    df2.append({'friend_id':f,'friend_rating':bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==f)]['stars_y'].item(),'user_id':u,'user_rating':bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==u)]['stars_y'].item()}, ignore_index=True)

# %%
friend_id =[]
user_id =[]
user_rating = []
friend_rating = []
business_id = []
for b in bus_review['business_id']:
    for u in bus_review[bus_review['business_id']==b]['user_id']:
        for F in user[user['user_id']==u]['friends']:
            for f in F:
                if f in (bus_review[bus_review['business_id']==b]['user_id']).tolist():
                    business_id.append(b)
                    friend_id.append(f)
                    user_id.append(u)
                    user_rating.append(bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==u)]['stars_y'].item())
                    friend_rating.append(bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==f)]['stars_y'].item())
dic = {'business_id':business_id,'user_id':user_id,'friend_id':friend_id,'user_rating':user_rating,'friend_rating':friend_rating}
df2 = pd.DataFrame(data=dic)

# %%
user_rating

# %%
#if 'VKriBUODDKCcDOfmgoeSUQ' in bus_review[bus_review['business_id']=='WwwYZakdSQM9174gdZdUIA']['user_id']:
    print ('yes')

# %%
(bus_review[bus_review['business_id']==b]['user_id']).tolist()

# %%
bus_review[(bus_review['business_id']==b) & (bus_review['user_id']=='VKriBUODDKCcDOfmgoeSUQ')]['stars_y'].item()

# %%
#if '6ay90tzcBoxPsvh2tX_ouw' in bus_review[bus_review['business_id']=='WwwYZakdSQM9174gdZdUIA']['user_id'].tolist():
    print('Yes')

# %%
df = pd.DataFrame(columns = ['friend_id','friend_rating','user_id','user_rating'])

# %%
df2 = pd.DataFrame(columns = ['friend_id'])

# %%
f

# %% [markdown]
# ##

# %%
print('friend:{},user:{}, with rating of {} and user rating {}'.format(f,u,bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==f)]['stars_y'].item(),bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==u)]['stars_y'].item()))

# %%
df.append({'friend_id':f,'friend_rating':bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==f)]['stars_y'].item(),
           'user_id':u,'user_rating':bus_review[(bus_review['business_id']==b) & (bus_review['user_id']==u)]['stars_y'].item()}, ignore_index=True)
